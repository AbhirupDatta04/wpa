# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhirupDatta04/wpa/blob/main/notebooks/wealth_analytics_data_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install faker pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

num_users = 1000

users = []

for i in range(num_users):
    users.append({
        "user_id": i + 1,
        "signup_date": fake.date_between(start_date='-1y', end_date='today'),
        "country": random.choice(["India", "USA", "UK"]),
        "account_type": random.choice(["retail", "premium"]),
        "risk_profile": random.choice(["low", "medium", "high"])
    })

users_df = pd.DataFrame(users)

users_df.head()
# Out:
#    user_id signup_date country account_type risk_profile
# 0        1  2026-01-25   India      premium         high
# 1        2  2025-06-13      UK       retail         high
# 2        3  2025-11-15   India       retail       medium
# 3        4  2025-08-26      UK      premium       medium
# 4        5  2025-05-27      UK       retail         high

# %%
users_df.to_csv("users.csv", index=False)

# %%
users_df.head()
# Out:
#    user_id signup_date country account_type risk_profile
# 0        1  2026-01-25   India      premium         high
# 1        2  2025-06-13      UK       retail         high
# 2        3  2025-11-15   India       retail       medium
# 3        4  2025-08-26      UK      premium       medium
# 4        5  2025-05-27      UK       retail         high
