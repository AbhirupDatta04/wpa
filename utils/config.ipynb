# %%
# ============================================================
# utils/config.ipynb — Central config. %run this first.
# ============================================================

BUCKET_NAME = 'wealth-analytics-data-lake'

PATHS = {
    'raw':    f'gs://{BUCKET_NAME}/raw/',
    'bronze': f'gs://{BUCKET_NAME}/bronze/',
    'silver': f'gs://{BUCKET_NAME}/silver/',
    'gold':   f'gs://{BUCKET_NAME}/gold/',
}

DATASETS = ['users', 'trades', 'sessions', 'events']
NUM_USERS = 1000

print('✅ Config loaded')
print(f'   Bucket: {BUCKET_NAME}')
print(f'   Layers: {list(PATHS.keys())}')
